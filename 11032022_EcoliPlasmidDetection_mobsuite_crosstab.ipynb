# %%
import os
import pandas as pd

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_HLF = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Filtered/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_HLF_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_HLF.append(isolate_mobsuite_results)

all_mobsuite_results_HLF = pd.concat(all_mobsuite_results_HLF)

print(all_mobsuite_results_HLF)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Filtered/EC-B1-9226-C5-H-CuN-CeP_HLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Filtered/EC-C-23315-C5-H-CuP-CeP_HLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Filtered/EC-D-9226-2S1-D-CuP-CeP_HLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Filtered/EC-A-4957-3S1-D-CuP-CeN_HLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Filtered/EC-A-4957-C3-H-CuP-CeP_HLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Filtered/EC-E-3862-S2-D-CuP-CeP_HLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Filtered/EC-A-6245-C4-H-CuP-CeP_HLF_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_HLUF = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Unfiltered/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_HLUF_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_HLUF.append(isolate_mobsuite_results)

all_mobsuite_results_HLUF = pd.concat(all_mobsuite_results_HLUF)

print(all_mobsuite_results_HLUF)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Unfiltered/EC-B1-7578-1L2-D-CuP-CeP_HLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Unfiltered/EC-C-23315-C5-H-CuP-CeP_HLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Unfiltered/EC-B1-9413-C4-H-CuP-CeP_HLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Unfiltered/EC-D-9226-2S1-D-CuP-CeP_HLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Unfiltered/EC-B1-9226-C5-H-CuN-CeP_HLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Ligation_Unfiltered/EC-E-2402-1H1-D-CuP-CeP_HLUF_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_HRF = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Filtered/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_HRF_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_HRF.append(isolate_mobsuite_results)

all_mobsuite_results_HRF = pd.concat(all_mobsuite_results_HRF)

print(all_mobsuite_results_HRF)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Filtered/EC-A-0205-C9-H-CuP-CeP_HRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Filtered/EC-E-3862-S2-D-CuP-CeP_HRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Filtered/EC-B1-9413-C4-H-CuP-CeP_HRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Filtered/EC-A-9619-3S1-D-CuP-CeP_HRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Filtered/EC-A-6245-C4-H-CuP-CeP_HRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Filtered/EC-E-6245-2L1-D-CuP-CeP_HRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Filtered/EC-E-2402-1H1-D-CuP-CeP_HRF_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_HRUF = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Unfiltered/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_HRUF_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_HRUF.append(isolate_mobsuite_results)

all_mobsuite_results_HRUF = pd.concat(all_mobsuite_results_HRUF)

print(all_mobsuite_results_HRUF)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Unfiltered/EC-G-9619-2L1-D-CuP-CeP_HRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Unfiltered/EC-C-23315-C5-H-CuP-CeP_HRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Unfiltered/EC-G-0205-3S1-D-CuP-CeP_HRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Unfiltered/EC-C-6245-1H1-D-CuP-CeP_HRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Unfiltered/EC-B1-9413-C4-H-CuP-CeP_HRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Unfiltered/EC-E-2402-1H1-D-CuP-CeP_HRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Hybrid_Rapid_Unfiltered/EC-D-9226-2S1-D-CuP-CeP_HRUF_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LLF = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LLF_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LLF.append(isolate_mobsuite_results)

all_mobsuite_results_LLF = pd.concat(all_mobsuite_results_LLF)

print(all_mobsuite_results_LLF)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered/EC-B1-7578-1L2-D-CuP-CeP_LLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered/EC-A-4957-C3-H-CuP-CeP_LLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered/EC-B2-0012-2L1-D-CuN-CeP_LLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered/EC-E-3862-S2-D-CuP-CeP_LLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered/EC-B1-2402-C3-H-CuP-CeN_LLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered/EC-E-6245-2L1-D-CuP-CeP_LLF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered/EC-D-9226-3H1-D-CuP-CeP_LLF_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LLUF = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LLUF_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LLUF.append(isolate_mobsuite_results)

all_mobsuite_results_LLUF = pd.concat(all_mobsuite_results_LLUF)

print(all_mobsuite_results_LLUF)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered/EC-A-4957-3S1-D-CuP-CeN_LR_LUF_LLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered/EC-A-4957-C3-H-CuP-CeP_LR_LUF_LLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered/EC-B1-2402-C3-H-CuP-CeN_LR_LUF_LLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered/EC-D-9226-3H1-D-CuP-CeP_LR_LUF_LLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered/EC-E-2402-1H1-D-CuP-CeP_LR_LUF_LLUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered/EC-A-0205-C9-H-CuP-CeP_LR_LUF_LLUF_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LLFM = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LLFM_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LLFM.append(isolate_mobsuite_results)

all_mobsuite_results_LLFM = pd.concat(all_mobsuite_results_LLFM)

print(all_mobsuite_results_LLFM)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka/EC-D-9226-3H1-D-CuP-CeP_LFM_LLFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka/EC-A-0012-C5-H-CuP-CeN_LLFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka/EC-E-6245-2L1-D-CuP-CeP_LFM_LLFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka/EC-G-0205-3S1-D-CuP-CeP_LFM_LLFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka/EC-A-4957-C3-H-CuP-CeP_LFM_LLFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka/EC-A-0012-C5-H-CuP-CeN_LFM_LLFM_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LLFMP = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka_Pilon/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LLFMP_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LLFMP.append(isolate_mobsuite_results)

all_mobsuite_results_LLFMP = pd.concat(all_mobsuite_results_LLFMP)

print(all_mobsuite_results_LLFMP)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka_Pilon/EC-B1-9413-C4-H-CuP-CeP_LLFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka_Pilon/EC-C-23315-C5-H-CuP-CeP_LLFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka_Pilon/EC-A-9619-3S1-D-CuP-CeP_LLFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka_Pilon/EC-B1-7578-1L2-D-CuP-CeP_LLFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka_Pilon/EC-D-9226-2S1-D-CuP-CeP_LLFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Filtered_Medaka_Pilon/EC-G-0205-3S1-D-CuP-CeP_LLFMP_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LLUFM = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LLUFM_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LLUFM.append(isolate_mobsuite_results)

all_mobsuite_results_LLUFM = pd.concat(all_mobsuite_results_LLUFM)

print(all_mobsuite_results_LLUFM)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka/EC-A-0205-C9-H-CuP-CeP_LLUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka/EC-D-9226-2S1-D-CuP-CeP_LLUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka/EC-E-2402-1H1-D-CuP-CeP_LLUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka/EC-B2-0012-2L1-D-CuN-CeP_LLUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka/EC-B1-2402-C3-H-CuP-CeN_LLUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka/EC-A-4957-C3-H-CuP-CeP_LLUFM_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LLUFMP = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka_Pilon/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LLUFMP_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LLUFMP.append(isolate_mobsuite_results)

all_mobsuite_results_LLUFMP = pd.concat(all_mobsuite_results_LLUFMP)

print(all_mobsuite_results_LLUFMP)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka_Pilon/EC-A-9619-3S1-D-CuP-CeP_LLUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka_Pilon/EC-E-3862-S2-D-CuP-CeP_LLUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka_Pilon/EC-B1-7578-1L2-D-CuP-CeP_LLUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka_Pilon/EC-A-6245-C4-H-CuP-CeP_LLUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka_Pilon/EC-E-2402-1H1-D-CuP-CeP_LLUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Ligation_Unfiltered_Medaka_Pilon/EC-E-6245-2L1-D-CuP-CeP_LLUFMP_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LRF = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LRF_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LRF.append(isolate_mobsuite_results)

all_mobsuite_results_LRF = pd.concat(all_mobsuite_results_LRF)

print(all_mobsuite_results_LRF)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered/EC-A-6245-C4-H-CuP-CeP_LRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered/EC-A-4957-3S1-D-CuP-CeN_LRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered/EC-E-3862-S2-D-CuP-CeP_LRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered/EC-B1-9226-C5-H-CuN-CeP_LRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered/EC-A-0012-C5-H-CuP-CeN_LRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered/EC-B2-0012-2L1-D-CuN-CeP_LRF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered/EC-C-23315-C5-H-CuP-CeP_LRF_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LRFM = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LRFM_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LRFM.append(isolate_mobsuite_results)

all_mobsuite_results_LRFM = pd.concat(all_mobsuite_results_LRFM)

print(all_mobsuite_results_LRFM)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka/EC-B1-9226-C5-H-CuN-CeP_LRFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka/EC-G-0205-3S1-D-CuP-CeP_LRFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka/EC-D-9226-3H1-D-CuP-CeP_LRFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka/EC-C-6245-1H1-D-CuP-CeP_LRFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka/EC-B2-0012-2L1-D-CuN-CeP_LRFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka/EC-A-4957-C3-H-CuP-CeP_LRFM_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LRFMP = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka_Pilon/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LRFMP_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LRFMP.append(isolate_mobsuite_results)

all_mobsuite_results_LRFMP = pd.concat(all_mobsuite_results_LRFMP)

print(all_mobsuite_results_LRFMP)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka_Pilon/EC-E-6245-2L1-D-CuP-CeP_LRFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka_Pilon/EC-G-0205-3S1-D-CuP-CeP_LRFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka_Pilon/EC-B1-7578-1L2-D-CuP-CeP_LRFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka_Pilon/EC-B2-0012-2L1-D-CuN-CeP_LRFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka_Pilon/EC-C-6245-1H1-D-CuP-CeP_LRFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Filtered_Medaka_Pilon/EC-B1-2402-C3-H-CuP-CeN_LRFMP_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LRUF = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LRUF_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LRUF.append(isolate_mobsuite_results)

all_mobsuite_results_LRUF = pd.concat(all_mobsuite_results_LRUF)

print(all_mobsuite_results_LRUF)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered/EC-A-6245-C4-H-CuP-CeP_LRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered/EC-D-9226-2S1-D-CuP-CeP_LRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered/EC-E-3862-S2-D-CuP-CeP_LRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered/EC-A-0012-C5-H-CuP-CeN_LRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered/EC-A-4957-3S1-D-CuP-CeN_LRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered/EC-B2-0012-2L1-D-CuN-CeP_LRUF_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered/EC-B1-2402-C3-H-CuP-CeN_LRUF_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LRUFM = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LRUFM_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LRUFM.append(isolate_mobsuite_results)

all_mobsuite_results_LRUFM = pd.concat(all_mobsuite_results_LRUFM)

print(all_mobsuite_results_LRUFM)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka/EC-B1-9226-C5-H-CuN-CeP_LRUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka/EC-A-0205-C9-H-CuP-CeP_LRUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka/EC-C-23315-C5-H-CuP-CeP_LRUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka/EC-E-3862-S2-D-CuP-CeP_LRUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka/EC-B1-2402-C3-H-CuP-CeN_LRUFM_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka/EC-B1-9413-C4-H-CuP-CeP_LRUFM_mobsuite/mobtyper_results.txt
# ...

# %%
import pandas as pd
from pathlib import Path
all_mobsuite_results_LRUFMP = []

mobsuite_results_directory = "/home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka_Pilon/"
for mobsuite_output in Path(mobsuite_results_directory).glob('*_LRUFMP_mobsuite/mobtyper_results.txt'):

    isolate_name = mobsuite_output.parts[6]

    print(f"Parsing {mobsuite_output}")
    isolate_mobsuite_results = pd.read_csv(mobsuite_output, sep='\t')
    isolate_mobsuite_results['Isolate_Pathname'] = isolate_name

    all_mobsuite_results_LRUFMP.append(isolate_mobsuite_results)

all_mobsuite_results_LRUFMP = pd.concat(all_mobsuite_results_LRUFMP)

print(all_mobsuite_results_LRUFMP)
# Out:
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka_Pilon/EC-B1-9413-C4-H-CuP-CeP_LRUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka_Pilon/EC-G-0205-3S1-D-CuP-CeP_LRUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka_Pilon/EC-B1-2402-C3-H-CuP-CeN_LRUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka_Pilon/EC-A-4957-3S1-D-CuP-CeN_LRUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka_Pilon/EC-A-9619-3S1-D-CuP-CeP_LRUFMP_mobsuite/mobtyper_results.txt
# Parsing /home/haley/Desktop/Complete_Assemblies_Plasmid/Long_Rapid_Unfiltered_Medaka_Pilon/EC-G-9619-2L1-D-CuP-CeP_LRUFMP_mobsuite/mobtyper_results.txt
# ...

# %%
frames = [all_mobsuite_results_HLF, all_mobsuite_results_HLUF, all_mobsuite_results_HRF, all_mobsuite_results_HRUF, all_mobsuite_results_LLF, all_mobsuite_results_LLFM, all_mobsuite_results_LLFMP, all_mobsuite_results_LLUF, all_mobsuite_results_LLUFM, all_mobsuite_results_LLUFMP, all_mobsuite_results_LRF, all_mobsuite_results_LRFM, all_mobsuite_results_LRFMP, all_mobsuite_results_LRUF, all_mobsuite_results_LRUFM, all_mobsuite_results_LRUFMP]
result = pd.concat(frames)

# %%
result.to_csv('11012022_All_20_Isolates_All_Assemblies_mobsuite_results_raw.csv')

# %%
sample_id = result['sample_id']
sample_id2= [x.split(':')[1] for x in sample_id]
result['sample_id'] = sample_id2
result
#set index as the isolate names
result_index = result.set_index('Isolate_Pathname')

# %%
result_index.to_csv('11012022_All_20_Isolates_All_Assemblies_mobsuite_results_processed.csv')

# %%
result_sorted = result_index.sort_index()

# %%
result_sorted.to_csv('11012022_All_20_Isolates_All_Assemblies_mobsuite_results_processed_sorted.csv')

# %%
plasmidisolatecrosstab = pd.crosstab(result_sorted.index, result_sorted.sample_id, margins=True)

# %%
plasmidisolatecrosstab.to_csv("11012022_EcoliPlasmidDetection_isolates_crosstab_mobsuite.csv")
